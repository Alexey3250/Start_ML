# %%
import warnings
warnings.filterwarnings('ignore')

### Установим красивые дефолтные настройки
### Может быть лень постоянно прописывать
### У графиков параметры цвета, размера, шрифта
### Можно положить их в словарь дефолтных настроек

import matplotlib as mlp

mlp.rcParams['lines.linewidth'] = 5
mlp.rcParams['xtick.major.size'] = 20
mlp.rcParams['xtick.major.width'] = 5
mlp.rcParams['xtick.labelsize'] = 20
mlp.rcParams['xtick.color'] = '#FF5533'

mlp.rcParams['ytick.major.size'] = 20
mlp.rcParams['ytick.major.width'] = 5
mlp.rcParams['ytick.labelsize'] = 20
mlp.rcParams['ytick.color'] = '#FF5533'

mlp.rcParams['axes.labelsize'] = 20
mlp.rcParams['axes.titlesize'] = 20
mlp.rcParams['axes.titlecolor'] = '#00B050'
mlp.rcParams['axes.labelcolor'] = '#00B050'

import pandas as pd

data = pd.read_csv('ks_crashed.csv')

data.head(20)
# Out:
#                                              Название Главная категория  \
# 0               Don't Call it a Comeback "Telescopes"             Music
# 1   Me & You Coordinating Sunglasses- Optical Qual...               NaN
# 2          New Carts for Istanbul Street Food Vendors              Food
# 3               New Improv Comedy Venue in Des Moines           Theater
# 4                              The Seer and the Sword      Film & Video
# 5   The Wild World of Ogots - YOU Become an Ogot (...        Publishing
# 6   VIGATAR, the fitness-machine that lets you pla...        Technology
# 7    Escape Room Palm Springs - Real Life Escape Game             Games
# 8   The Grrrl has a new album called 'Through Ruin...             Music
# 9                                      The Tile House               Art
# 10                            Blunt P.I. - Web Series      Film & Video
# 11                Morbid Hype - Artists Tribue Shirts           Fashion
# 12              Maize Stalk Drinking Blood Marionette               Art
# 13                            Peculiar Show: Season 1      Film & Video
# 14                     Valeria Marcon's First Solo EP             Music
# 15                 QUAKERS: The Quiet Revolutionaries      Film & Video
# 16                Bring "Hang Time" to Life in Bronze               Art
# 17               Huelsy's Train Blog Visits St. Louis       Photography
# 18                                               SEED            Design
# 19                                          Jaye Cane             Music
#
#    Валюта  Собрано в долларах  Цель в долларах
# 0     USD              600.00           600.00
# 1     USD              502.00         10000.00
# 2     USD             2414.00          1400.00
# 3     USD            10030.88         10000.00
# 4     USD                0.00         10000.00
# 5     USD             1305.00          1075.00
# 6     EUR             4395.53        131879.15
# 7     NaN             2553.00          7500.00
# 8     USD              185.00           178.00
# 9     NaN             7360.00          7000.00
# 10    USD             4115.00          4000.00
# 11    NaN               29.00          3000.00
# 12    USD              908.00           550.00
# 13    USD             2645.00          2500.00
# 14    CHF             3133.37          3010.93
# 15    USD            11492.00              NaN
# 16    USD              298.00          4500.00
# 17    USD                0.00          2500.00
# 18    NaN             4837.00          4000.00
# 19    NaN                0.00         20000.00

# %%
### Сколько потеряем данных, если просто дропнем все строки с NaN?

print(f'Потеряем {data.shape[0] - data.dropna().shape[0]} объектов')

print(f'Это {round(100*(data.shape[0] - data.dropna().shape[0])/data.shape[0], 1)}% выборки')
# Out:
# Потеряем 89785 объектов
# Это 27.1% выборки

# %%
data.isna().sum()
# Out:
# Название                  3
# Главная категория     32906
# Валюта                33200
# Собрано в долларах        0
# Цель в долларах       33143
# dtype: int64

# %%
### Начнем с категориальных  признаков!
### Прием №1: Заполнить пропуски самым популярным классом

popular_category = data['Главная категория'].value_counts().index[0]
data['Главная категория'] = data['Главная категория'].fillna(popular_category)

# %%
### Прием №2: Заполнить пропуски новой категорией

data['Валюта'] = data['Валюта'].fillna('Неизвестная валюта')

# %%
### Перейдем теперь к нашему единственному вещественному признаку!

mean = data['Цель в долларах'].mean()
median = data['Цель в долларах'].median()

data['Цель в долларах'].fillna(mean)
# Out:
# 0           600.000000
# 1         10000.000000
# 2          1400.000000
# 3         10000.000000
# 4         10000.000000
#               ...
# 331670     9000.000000
# 331671     2501.450000
# 331672     1500.000000
# 331673    42352.372792
# 331674     4000.000000
# Name: Цель в долларах, Length: 331675, dtype: float64

# %%
### А давайте будем заполнять пропуски, смотря на похожие объекты!
### Например, ориентируясь на Валюту

grouped_means = data.groupby('Главная категория')['Цель в долларах'].transform("mean")

# %%
data['Цель в долларах'] = data['Цель в долларах'].fillna(grouped_means)

# %%
### С неймингами ничего не поделаешь. Их можно игнорировать или дропнуть

data.isna().sum()
# Out:
# Название              3
# Главная категория     0
# Валюта                0
# Собрано в долларах    0
# Цель в долларах       0
# dtype: int64

# %% [markdown]
# ### Исследование выбросов

# %%
data
# Out:
#                                                  Название Главная категория  \
# 0                   Don't Call it a Comeback "Telescopes"             Music
# 1       Me & You Coordinating Sunglasses- Optical Qual...      Film & Video
# 2              New Carts for Istanbul Street Food Vendors              Food
# 3                   New Improv Comedy Venue in Des Moines           Theater
# 4                                  The Seer and the Sword      Film & Video
# ...                                                   ...               ...
# 331670  Launch Ladies - A children's book about the Wo...        Publishing
# 331671  TurnAround//The End Needs A Beginning Album Re...             Music
# 331672  Celtic inspired band looking to move forward w...             Music
# 331673  Listening & Speaking in Virtual Reality: 5 Int...        Technology
# 331674              Come with us . . . Into the Dark Wood             Dance
#
#                     Валюта  Собрано в долларах  Цель в долларах
# 0                      USD              600.00       600.000000
# 1                      USD              502.00     10000.000000
# 2                      USD             2414.00      1400.000000
# 3                      USD            10030.88     10000.000000
# 4                      USD                0.00     10000.000000
# ...                    ...                 ...              ...
# 331670                 USD            18808.00      9000.000000
# 331671                 GBP                0.00      2501.450000
# 331672                 USD                0.00      1500.000000
# 331673  Неизвестная валюта              200.00     98961.220521
# 331674                 USD             4847.00      4000.000000
#
# [331675 rows x 5 columns]

# %%
from matplotlib import pyplot as plt

# %%
### Нарисуем гистограмму 

fig = plt.figure()
fig.set_size_inches((10, 16))

data[data['Собрано в долларах']<100000]["Собрано в долларах"].hist(bins=100)

plt.show()

# %%
### Нарисуем ящик с усами
from matplotlib import pyplot as plt

fig = plt.figure()

fig.set_size_inches((10, 16))

plt.boxplot(data['Собрано в долларах'].values)

plt.show()

# %%
from matplotlib import pyplot as plt

fig = plt.figure()

fig.set_size_inches((10, 16))

plt.boxplot(data['Собрано в долларах'].values)
plt.ylim(0, 50000)

plt.show()

# %%
### Расчитаем длину усиков
q_low = data['Собрано в долларах'].quantile(0.25)
q_high = data['Собрано в долларах'].quantile(0.75)

tentacle_length = q_high - q_low

# %%
tentacle_length

upper_tentacle = q_high + 3 * tentacle_length

# %%
upper_tentacle
# Out:
# 18282.0

# %%
### Уберем все данные, в которых таргет - за пределами верхнего усика
data[data['Собрано в долларах']<upper_tentacle]
# Out:
#                                                  Название Главная категория  \
# 0                   Don't Call it a Comeback "Telescopes"             Music
# 1       Me & You Coordinating Sunglasses- Optical Qual...      Film & Video
# 2              New Carts for Istanbul Street Food Vendors              Food
# 3                   New Improv Comedy Venue in Des Moines           Theater
# 4                                  The Seer and the Sword      Film & Video
# ...                                                   ...               ...
# 331669                    Jared Horgan's Huge Opportunity             Music
# 331671  TurnAround//The End Needs A Beginning Album Re...             Music
# 331672  Celtic inspired band looking to move forward w...             Music
# 331673  Listening & Speaking in Virtual Reality: 5 Int...        Technology
# 331674              Come with us . . . Into the Dark Wood             Dance
#
#                     Валюта  Собрано в долларах  Цель в долларах
# 0                      USD              600.00       600.000000
# 1                      USD              502.00     10000.000000
# 2                      USD             2414.00      1400.000000
# 3                      USD            10030.88     10000.000000
# 4                      USD                0.00     10000.000000
# ...                    ...                 ...              ...
# 331669                 USD              505.00      8000.000000
# 331671                 GBP                0.00      2501.450000
# 331672                 USD                0.00      1500.000000
# 331673  Неизвестная валюта              200.00     98961.220521
# 331674                 USD             4847.00      4000.000000
#
# [303961 rows x 5 columns]

# %% [markdown]
# ## TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
### Зафиттим наши данные в TfidfVectorizer
data = data.dropna()


tfidf = TfidfVectorizer()
tfidf.fit(data['Название'])
# Out:
# TfidfVectorizer()

# %%
### Посмотрим как выглядит наш первый документ (первое описание)
first_document = data['Название'][0]
first_document
# Out:
# 'Don\'t Call it a Comeback "Telescopes"'

# %%
### Векторизуем данное описание через tf-idf
tfidf.transform([first_document])
tfidf.transform([first_document]).todense()
# Out:
# matrix([[0., 0., 0., ..., 0., 0., 0.]])

# %%
tfidf.get_feature_names()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 tfidf.get_feature_names()
#
# AttributeError: 'TfidfVectorizer' object has no attribute 'get_feature_names'

# %%
### Посмотрим на содержимое этого вектора
df = pd.DataFrame(tfidf.transform([first_document]).T.todense(),
                  index=tfidf.get_feature_names(),
                  columns=['tfidf'])

df.sort_values('tfidf', ascending=False)[:50]
# Out:
#                tfidf
# telescopes  0.613898
# comeback    0.503584
# call        0.396683
# don         0.361875
# it          0.284996
# pilates     0.000000
# pilacca     0.000000
# pilafoot    0.000000
# pilar       0.000000
# pilares     0.000000
# pilatesex   0.000000
# pil         0.000000
# pilato      0.000000
# pilby       0.000000
# pilcher     0.000000
# pilchuck    0.000000
# pile        0.000000
# pila        0.000000
# 00          0.000000
# piksil      0.000000
# piles       0.000000
# piksi       0.000000
# piks        0.000000
# pikpark     0.000000
# piko        0.000000
# pikmin      0.000000
# pikliz      0.000000
# pikle       0.000000
# pikkpack    0.000000
# pikkey      0.000000
# pikey       0.000000
# pikestock   0.000000
# pikes       0.000000
# piled       0.000000
# pilferers   0.000000
# pilesar     0.000000
# piken       0.000000
# pillowcase  0.000000
# pillow      0.000000
# pilloohs    0.000000
# pillocks    0.000000
# pilllar     0.000000
# pillitteri  0.000000
# pillion     0.000000
# pille       0.000000
# pillbox     0.000000
# pillars     0.000000
# pillards    0.000000
# pillar      0.000000
# pillah      0.000000

# %%
df[df.values>0]
# Out:
#                tfidf
# call        0.396683
# comeback    0.503584
# don         0.361875
# it          0.284996
# telescopes  0.613898
