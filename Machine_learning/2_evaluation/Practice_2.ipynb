# %%
from IPython.display import Image
import pandas as pd
import numpy as np

# %% [markdown]
# ![kickstarter.jpg](attachment:kickstarter.jpg)

# %%
data = pd.read_csv('ks.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 data = pd.read_csv('ks.csv')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\io\parsers\readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\io\parsers\readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\io\parsers\readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\io\parsers\readers.py:1735, in TextFileReader._make_engine(self, f, engine)
#    1733     if "b" not in mode:
#    1734         mode += "b"
# -> 1735 self.handles = get_handle(
#    1736     f,
#    1737     mode,
#    1738     encoding=self.options.get("encoding", None),
#    1739     compression=self.options.get("compression", None),
#    1740     memory_map=self.options.get("memory_map", False),
#    1741     is_text=is_text,
#    1742     errors=self.options.get("encoding_errors", "strict"),
#    1743     storage_options=self.options.get("storage_options", None),
#    1744 )
#    1745 assert self.handles is not None
#    1746 f = self.handles.handle
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\io\common.py:856, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     851 elif isinstance(handle, str):
#     852     # Check whether the filename is to be opened in binary mode.
#     853     # Binary mode does not support 'encoding' and 'newline'.
#     854     if ioargs.encoding and "b" not in ioargs.mode:
#     855         # Encoding
# --> 856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#     859             encoding=ioargs.encoding,
#     860             errors=errors,
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
#     865         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ks.csv'

# %%
data.head()
# Out:
#                                             Название    Категория  \
# 0              Don't Call it a Comeback "Telescopes"        Music
# 1                           Arcade County (Canceled)        Games
# 2        Hayashi Skate Co. Solar Skateboard backpack  Accessories
# 3  Me & You Coordinating Sunglasses- Optical Qual...  Accessories
# 4         New Carts for Istanbul Street Food Vendors         Food
#
#   Главная категория Валюта     Дедлайн      Дата публикации   Состояние  \
# 0             Music    USD  2013-01-10  2012-12-09 06:03:52  successful
# 1             Games    USD  2012-04-29  2012-03-30 23:40:45    canceled
# 2           Fashion    CAD  2017-07-22  2017-05-23 23:00:13    canceled
# 3           Fashion    USD  2016-11-18  2016-10-19 22:06:41      failed
# 4              Food    USD  2015-05-17  2015-04-17 18:10:47  successful
#
#    Инвесторов Страна  Собрано в долларах  Цель в долларах
# 0          23     US              600.00           600.00
# 1           5     US               71.00          9000.00
# 2           8     CA              360.36          2391.77
# 3          20     US              502.00         10000.00
# 4          62     US             2414.00          1400.00

# %%
data.shape
# Out:
# (378661, 11)

# %%
### Оставим только нужные состояния

data = data[data['Состояние'].isin(['failed', 'successful'])]

# %% [markdown]
# ### Что берем за таргет? 2 варианта:
#
# - Будем решать задачу классификации, разметив объекты следующим образом: те проекты, у которых успешный статус, единичкой, а остальные ноликами
#
# - Можем предсказывать просто собранное количество денег, применять модель, а потом уже смотреть, нужная ли сумма получилось. Тогда мы решаем задачу регрессии.

# %%
### Создадим колонку таргет1 (бинарный таргет)

data.loc[(data['Состояние'] == 'failed'), 'таргет1'] = 0
data['таргет1'] = data['таргет1'].fillna(1)

# %%
data = data.drop('Состояние', axis=1)

# %%
### Создадим вещественную колонку таргет2
data = data.rename({'Собрано в долларах':'таргет2'}, axis=1)
data.head()
# Out:
#                                             Название    Категория  \
# 0              Don't Call it a Comeback "Telescopes"        Music
# 3  Me & You Coordinating Sunglasses- Optical Qual...  Accessories
# 4         New Carts for Istanbul Street Food Vendors         Food
# 5              New Improv Comedy Venue in Des Moines      Theater
# 6                             The Seer and the Sword       Shorts
#
#   Главная категория Валюта     Дедлайн      Дата публикации  Инвесторов  \
# 0             Music    USD  2013-01-10  2012-12-09 06:03:52          23
# 3           Fashion    USD  2016-11-18  2016-10-19 22:06:41          20
# 4              Food    USD  2015-05-17  2015-04-17 18:10:47          62
# 5           Theater    USD  2013-06-17  2013-05-03 16:17:21          86
# 6      Film & Video    USD  2012-08-11  2012-07-12 05:19:53           0
#
#   Страна   таргет2  Цель в долларах  таргет1
# 0     US    600.00            600.0      1.0
# 3     US    502.00          10000.0      0.0
# 4     US   2414.00           1400.0      1.0
# 5     US  10030.88          10000.0      1.0
# 6     US      0.00          10000.0      0.0

# %% [markdown]
# ### Чтобы получить матрицу объектов, зачастую нужно обработать сырые данные, то есть извлечь из имеющихся таблиц признаки там, где они не даны явно

# %%
### Оставим от колонок с датами разницу в днях 

data['Дедлайн'] = pd.to_datetime(data['Дедлайн'])
data['Дата публикации'] = pd.to_datetime(data['Дата публикации'])

# %%
data['Срок'] = (data['Дедлайн'] - data['Дата публикации']).dt.days

# %%
### Выделим год запуска проекта
data['Год публикации'] = data['Дата публикации'].dt.year

# %%
data.head()
# Out:
#                                             Название    Категория  \
# 0              Don't Call it a Comeback "Telescopes"        Music
# 3  Me & You Coordinating Sunglasses- Optical Qual...  Accessories
# 4         New Carts for Istanbul Street Food Vendors         Food
# 5              New Improv Comedy Venue in Des Moines      Theater
# 6                             The Seer and the Sword       Shorts
#
#   Главная категория Валюта    Дедлайн     Дата публикации  Инвесторов Страна  \
# 0             Music    USD 2013-01-10 2012-12-09 06:03:52          23     US
# 3           Fashion    USD 2016-11-18 2016-10-19 22:06:41          20     US
# 4              Food    USD 2015-05-17 2015-04-17 18:10:47          62     US
# 5           Theater    USD 2013-06-17 2013-05-03 16:17:21          86     US
# 6      Film & Video    USD 2012-08-11 2012-07-12 05:19:53           0     US
#
#     таргет2  Цель в долларах  таргет1  Срок  Год публикации
# 0    600.00            600.0      1.0    31            2012
# 3    502.00          10000.0      0.0    29            2016
# 4   2414.00           1400.0      1.0    29            2015
# 5  10030.88          10000.0      1.0    44            2013
# 6      0.00          10000.0      0.0    29            2012

# %% [markdown]
# ### Иногда может казаться, что признаков мало. Стоит подумать над тем, что еще может объяснять таргет-переменную.

# %%
Macro = pd.read_excel("macrofeatures.xlsx", engine="openpyxl")

Macro.head()
# Out:
#    Unnamed: 0  Close_brent  Close_sugar  Close_cereals  Close_index_moex  \
# 0           0        34.41        13.97         442.75           1797.27
# 1           1        35.06        14.24         445.25           1803.89
# 2           2        35.13        14.00         443.25           1816.73
# 3           3        36.64        14.36         445.00           1840.17
# 4           4        36.60        14.39         438.50           1844.17
#
#    Close_index_moex_10  Close_index_RGBI  Close_index_RTS_oil_and_gas  \
# 0              3940.81            125.59                       123.40
# 1              3977.35            126.44                       124.22
# 2              4027.23            126.90                       125.38
# 3              4084.24            126.87                       126.69
# 4              4087.06            127.78                       129.72
#
#    Close_index_RTS_metallurgy  Close_index_RTS_consumer_sector  \
# 0                      111.97                           196.55
# 1                      112.51                           198.03
# 2                      113.44                           200.13
# 3                      114.66                           200.32
# 4                      117.09                           204.30
#
#    Close_index_RTS_telecom  Close_index_RTS_finance  \
# 0                    70.17                   140.57
# 1                    70.56                   142.64
# 2                    71.94                   145.45
# 3                    72.41                   147.22
# 4                    74.26                   150.04
#
#    Close_index_RTS_transport  Close_index_RTS_chemicals  \
# 0                      27.06                     177.38
# 1                      27.43                     179.48
# 2                      28.06                     181.56
# 3                      28.49                     186.76
# 4                      30.12                     190.67
#
#    Close_index_RTS_broad_market  Close_index_RTS_electricity dlk_cob_date
# 0                        530.59                        32.49   2016-02-24
# 1                        536.20                        33.07   2016-02-25
# 2                        544.73                        33.55   2016-02-26
# 3                        552.82                        34.41   2016-02-29
# 4                        565.45                        34.96   2016-03-01

# %%
### Смерджим колонки. Оставим от макрофичей какую-нибудь одну.

Macro = Macro[['Close_brent', 'dlk_cob_date']].drop_duplicates()

# %%
Macro['dlk_cob_date'] = pd.to_datetime(Macro['dlk_cob_date'])

# %%
data['Дата публикации'] = data['Дата публикации'].astype('datetime64[ns]')

# %%
data = pd.merge(data,
         Macro,
         left_on=['Дата публикации'],
         right_on=['dlk_cob_date'],
         how='left')

# %%
data = data.sort_values('Дата публикации')

# %%
data['Close_brent'] = data['Close_brent'].fillna(34.41)

# %%
data = data.drop(['Дедлайн', 'Дата публикации', 'dlk_cob_date'], axis=1)

# %%
data.head()
# Out:
#                                                  Название     Категория  \
# 176128  Grace Jones Does Not Give A F$#% T-Shirt (limi...       Fashion
# 241929                     CRYSTAL ANTLERS UNTITLED MOVIE        Shorts
# 244460                                drawing for dollars  Illustration
# 80845                        Offline Wikipedia iPhone app      Software
# 181197                                         Pantshirts       Fashion
#
#        Главная категория Валюта  Инвесторов Страна  таргет2  Цель в долларах  \
# 176128           Fashion    USD          30     US    625.0           1000.0
# 241929      Film & Video    USD           3     US     22.0          80000.0
# 244460               Art    USD           3     US     35.0             20.0
# 80845         Technology    USD          25     US    145.0             99.0
# 181197           Fashion    USD          10     US    387.0           1900.0
#
#         таргет1  Срок  Год публикации  Close_brent
# 176128      0.0    39            2009        34.41
# 241929      0.0    87            2009        34.41
# 244460      1.0     8            2009        34.41
# 80845       1.0    79            2009        34.41
# 181197      0.0    28            2009        34.41

# %% [markdown]
# ### Финально, стоит избавиться от колонок, которые мы не считаем признаками

# %%
### Уберем колонки Дедлайн, Дата запуска, Инвесторы, Название, Страна

data = data.drop(['Страна', 'Инвесторов'], axis=1)

# %%
data.head()
# Out:
#                                                  Название     Категория  \
# 176128  Grace Jones Does Not Give A F$#% T-Shirt (limi...       Fashion
# 241929                     CRYSTAL ANTLERS UNTITLED MOVIE        Shorts
# 244460                                drawing for dollars  Illustration
# 80845                        Offline Wikipedia iPhone app      Software
# 181197                                         Pantshirts       Fashion
#
#        Главная категория Валюта  таргет2  Цель в долларах  таргет1  Срок  \
# 176128           Fashion    USD    625.0           1000.0      0.0    39
# 241929      Film & Video    USD     22.0          80000.0      0.0    87
# 244460               Art    USD     35.0             20.0      1.0     8
# 80845         Technology    USD    145.0             99.0      1.0    79
# 181197           Fashion    USD    387.0           1900.0      0.0    28
#
#         Год публикации  Close_brent
# 176128            2009        34.41
# 241929            2009        34.41
# 244460            2009        34.41
# 80845             2009        34.41
# 181197            2009        34.41

# %% [markdown]
# ## One-hot encoding

# %% [markdown]
# ![ONEHOT.png](attachment:ONEHOT.png)

# %%
### One-hot encoding колонки с валютой

data = pd.concat((data, pd.get_dummies(data['Валюта'])), axis=1)
data = data.drop(['Валюта'], axis=1)

# %%
data.head()
# Out:
#                                                  Название     Категория  \
# 176128  Grace Jones Does Not Give A F$#% T-Shirt (limi...       Fashion
# 241929                     CRYSTAL ANTLERS UNTITLED MOVIE        Shorts
# 244460                                drawing for dollars  Illustration
# 80845                        Offline Wikipedia iPhone app      Software
# 181197                                         Pantshirts       Fashion
#
#        Главная категория  таргет2  Цель в долларах  таргет1  Срок  \
# 176128           Fashion    625.0           1000.0      0.0    39
# 241929      Film & Video     22.0          80000.0      0.0    87
# 244460               Art     35.0             20.0      1.0     8
# 80845         Technology    145.0             99.0      1.0    79
# 181197           Fashion    387.0           1900.0      0.0    28
#
#         Год публикации  Close_brent  AUD  ...  EUR  GBP  HKD  JPY  MXN  NOK  \
# 176128            2009        34.41    0  ...    0    0    0    0    0    0
# 241929            2009        34.41    0  ...    0    0    0    0    0    0
# 244460            2009        34.41    0  ...    0    0    0    0    0    0
# 80845             2009        34.41    0  ...    0    0    0    0    0    0
# 181197            2009        34.41    0  ...    0    0    0    0    0    0
#
#         NZD  SEK  SGD  USD
# 176128    0    0    0    1
# 241929    0    0    0    1
# 244460    0    0    0    1
# 80845     0    0    0    1
# 181197    0    0    0    1
#
# [5 rows x 23 columns]

# %%
### Почистим данные от лишней информации 
data = data.drop('AUD', axis=1)

# %%
### Аналогично закодируем Главную категорию
data = pd.concat((data, pd.get_dummies(data['Главная категория'])), axis=1)
data = data.drop(['Главная категория'], axis=1)

# %%
data.head()
# Out:
#                                                  Название     Категория  \
# 176128  Grace Jones Does Not Give A F$#% T-Shirt (limi...       Fashion
# 241929                     CRYSTAL ANTLERS UNTITLED MOVIE        Shorts
# 244460                                drawing for dollars  Illustration
# 80845                        Offline Wikipedia iPhone app      Software
# 181197                                         Pantshirts       Fashion
#
#         таргет2  Цель в долларах  таргет1  Срок  Год публикации  Close_brent  \
# 176128    625.0           1000.0      0.0    39            2009        34.41
# 241929     22.0          80000.0      0.0    87            2009        34.41
# 244460     35.0             20.0      1.0     8            2009        34.41
# 80845     145.0             99.0      1.0    79            2009        34.41
# 181197    387.0           1900.0      0.0    28            2009        34.41
#
#         CAD  CHF  ...  Fashion  Film & Video  Food  Games  Journalism  Music  \
# 176128    0    0  ...        1             0     0      0           0      0
# 241929    0    0  ...        0             1     0      0           0      0
# 244460    0    0  ...        0             0     0      0           0      0
# 80845     0    0  ...        0             0     0      0           0      0
# 181197    0    0  ...        1             0     0      0           0      0
#
#         Photography  Publishing  Technology  Theater
# 176128            0           0           0        0
# 241929            0           0           0        0
# 244460            0           0           0        0
# 80845             0           0           1        0
# 181197            0           0           0        0
#
# [5 rows x 36 columns]

# %%
data = data.drop('Games', axis=1)

# %%
### А что с колонкой Категория?

len(data['Категория'].unique())
# Out:
# 159

# %% [markdown]
# ## Mean-target encoding (Счетчики)

# %% [markdown]
# ![%D0%A1%D1%87%D0%B5%D1%82%D1%87%D0%B8%D0%BA%D0%B8.png](attachment:%D0%A1%D1%87%D0%B5%D1%82%D1%87%D0%B8%D0%BA%D0%B8.png)

# %%
### Произведем mean-target-encoding колонки Категория

data['Категория'] = data['Категория'].map(data.groupby(['Категория'])['таргет2'].mean())

# %%
data.head()
# Out:
#                                                  Название    Категория  \
# 176128  Grace Jones Does Not Give A F$#% T-Shirt (limi...  6035.989239
# 241929                     CRYSTAL ANTLERS UNTITLED MOVIE  3591.033473
# 244460                                drawing for dollars  3661.424550
# 80845                        Offline Wikipedia iPhone app  4321.245721
# 181197                                         Pantshirts  6035.989239
#
#         таргет2  Цель в долларах  таргет1  Срок  Год публикации  Close_brent  \
# 176128    625.0           1000.0      0.0    39            2009        34.41
# 241929     22.0          80000.0      0.0    87            2009        34.41
# 244460     35.0             20.0      1.0     8            2009        34.41
# 80845     145.0             99.0      1.0    79            2009        34.41
# 181197    387.0           1900.0      0.0    28            2009        34.41
#
#         CAD  CHF  ...  Design  Fashion  Film & Video  Food  Journalism  Music  \
# 176128    0    0  ...       0        1             0     0           0      0
# 241929    0    0  ...       0        0             1     0           0      0
# 244460    0    0  ...       0        0             0     0           0      0
# 80845     0    0  ...       0        0             0     0           0      0
# 181197    0    0  ...       0        1             0     0           0      0
#
#         Photography  Publishing  Technology  Theater
# 176128            0           0           0        0
# 241929            0           0           0        0
# 244460            0           0           0        0
# 80845             0           0           1        0
# 181197            0           0           0        0
#
# [5 rows x 35 columns]

# %% [markdown]
# ## Определимся с таргетом

# %%
data = data.drop('таргет1', axis=1)

# %%
### Разделим данные на объекты и ответы

X = data.drop('таргет2', axis=1)
Y = data['таргет2']

# %%
Y
# Out:
# 176128    625.00
# 241929     22.00
# 244460     35.00
# 80845     145.00
# 181197    387.00
#            ...
# 247730    269.84
# 318187    544.77
# 264474    202.00
# 293634    265.00
# 23315     513.60
# Name: таргет2, Length: 331675, dtype: float64

# %%
X.to_csv('X_with_names.csv', index=False)

# %%
X.drop('Название', axis=1).to_csv('X_2.csv', index=False)

# %% [markdown]
# ### sklearn

# %%
### Сейчас будет магия!
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X, Y)

X['Предсказание'] = model.predict(X)

X.head()
# Out:
#           Категория  Цель в долларах  Срок  Год публикации  Close_brent  CAD  \
# 176128  6035.989239           1000.0    39            2009        34.41    0
# 241929  3591.033473          80000.0    87            2009        34.41    0
# 244460  3661.424550             20.0     8            2009        34.41    0
# 80845   4321.245721             99.0    79            2009        34.41    0
# 181197  6035.989239           1900.0    28            2009        34.41    0
#
#         CHF  DKK  EUR  GBP  ...  Fashion  Film & Video  Food  Journalism  \
# 176128    0    0    0    0  ...        1             0     0           0
# 241929    0    0    0    0  ...        0             1     0           0
# 244460    0    0    0    0  ...        0             0     0           0
# 80845     0    0    0    0  ...        0             0     0           0
# 181197    0    0    0    0  ...        1             0     0           0
#
#         Music  Photography  Publishing  Technology  Theater  Предсказание
# 176128      0            0           0           0        0   3462.151236
# 241929      0            0           0           0        0   5388.839779
# 244460      0            0           0           0        0  -1332.724207
# 80845       0            0           0           1        0   5271.256319
# 181197      0            0           0           0        0   2529.810713
#
# [5 rows x 33 columns]

# %%
data.head()
# Out:
#           Категория  таргет2  Цель в долларах  Срок  Год публикации  \
# 176128  6035.989239    625.0           1000.0    39            2009
# 241929  3591.033473     22.0          80000.0    87            2009
# 244460  3661.424550     35.0             20.0     8            2009
# 80845   4321.245721    145.0             99.0    79            2009
# 181197  6035.989239    387.0           1900.0    28            2009
#
#         Close_brent  CAD  CHF  DKK  EUR  ...  Fashion  Film & Video  Food  \
# 176128        34.41    0    0    0    0  ...        1             0     0
# 241929        34.41    0    0    0    0  ...        0             1     0
# 244460        34.41    0    0    0    0  ...        0             0     0
# 80845         34.41    0    0    0    0  ...        0             0     0
# 181197        34.41    0    0    0    0  ...        1             0     0
#
#         Journalism  Music  Photography  Publishing  Technology  Theater  \
# 176128           0      0            0           0           0        0
# 241929           0      0            0           0           0        0
# 244460           0      0            0           0           0        0
# 80845            0      0            0           0           1        0
# 181197           0      0            0           0           0        0
#
#          prediction
# 176128  3462.151236
# 241929  5388.839779
# 244460 -1332.724207
# 80845   5271.256319
# 181197  2529.810713
#
# [5 rows x 34 columns]

# %%
#Запишем результат в data.csv

# %%
X.to_csv('X.csv', index=False)
Y.to_csv('X.csv', index=False)
# Out:
#            Категория  Цель в долларах  Срок  Год публикации  Close_brent  CAD  \
# 176128   6035.989239          1000.00    39            2009        34.41    0
# 241929   3591.033473         80000.00    87            2009        34.41    0
# 244460   3661.424550            20.00     8            2009        34.41    0
# 80845    4321.245721            99.00    79            2009        34.41    0
# 181197   6035.989239          1900.00    28            2009        34.41    0
# ...              ...              ...   ...             ...          ...  ...
# 247730   7635.064778            35.98     2            2017        65.25    0
# 318187  38415.722876           271.03     4            2017        66.46    0
# 264474   6098.303122           200.00     3            2017        65.99    0
# 293634  38415.722876           250.00     1            2017        66.16    0
# 23315    1313.020012           392.06     2            2017        66.87    0
#
#         CHF  DKK  EUR  GBP  ...  Fashion  Film & Video  Food  Journalism  \
# 176128    0    0    0    0  ...        1             0     0           0
# 241929    0    0    0    0  ...        0             1     0           0
# 244460    0    0    0    0  ...        0             0     0           0
# 80845     0    0    0    0  ...        0             0     0           0
# 181197    0    0    0    0  ...        1             0     0           0
# ...     ...  ...  ...  ...  ...      ...           ...   ...         ...
# 247730    0    0    1    0  ...        0             0     0           0
# 318187    0    0    0    1  ...        0             0     0           0
# 264474    0    0    0    0  ...        1             0     0           0
# 293634    0    0    0    0  ...        0             0     0           0
# 23315     0    0    0    0  ...        0             0     0           0
#
#         Music  Photography  Publishing  Technology  Theater  Предсказание
# 176128      0            0           0           0        0   3462.151236
# 241929      0            0           0           0        0   5388.839779
# 244460      0            0           0           0        0  -1332.724207
# 80845       0            0           0           1        0   5271.256319
# 181197      0            0           0           0        0   2529.810713
# ...       ...          ...         ...         ...      ...           ...
# 247730      0            0           0           0        0   2930.483309
# 318187      0            0           0           0        0  36036.400220
# 264474      0            0           0           0        0   7814.978110
# 293634      0            0           0           0        0  39978.381778
# 23315       1            0           0           0        0  -3995.651240
#
# [331675 rows x 33 columns]

# %%
X.head()
# Out:
#           Категория  Цель в долларах  Срок  Год публикации  Close_brent  CAD  \
# 176128  6035.989239           1000.0    39            2009        34.41    0
# 241929  3591.033473          80000.0    87            2009        34.41    0
# 244460  3661.424550             20.0     8            2009        34.41    0
# 80845   4321.245721             99.0    79            2009        34.41    0
# 181197  6035.989239           1900.0    28            2009        34.41    0
#
#         CHF  DKK  EUR  GBP  ...  Fashion  Film & Video  Food  Journalism  \
# 176128    0    0    0    0  ...        1             0     0           0
# 241929    0    0    0    0  ...        0             1     0           0
# 244460    0    0    0    0  ...        0             0     0           0
# 80845     0    0    0    0  ...        0             0     0           0
# 181197    0    0    0    0  ...        1             0     0           0
#
#         Music  Photography  Publishing  Technology  Theater  Предсказание
# 176128      0            0           0           0        0   3462.151236
# 241929      0            0           0           0        0   5388.839779
# 244460      0            0           0           0        0  -1332.724207
# 80845       0            0           0           1        0   5271.256319
# 181197      0            0           0           0        0   2529.810713
#
# [5 rows x 33 columns]

# %%
Y.head()
# Out:
# 176128    625.0
# 241929     22.0
# 244460     35.0
# 80845     145.0
# 181197    387.0
# Name: таргет2, dtype: float64

# %%
### Посчитаем MSE

(((X['Предсказание'] - Y)**2).mean())**(1/2)
# Out:
# 95926.20225608691

# %%
X['Предсказание'] - Y
# Out:
# 176128     2837.151236
# 241929     5366.839779
# 244460    -1367.724207
# 80845      5126.256319
# 181197     2142.810713
#               ...
# 247730     2660.643309
# 318187    35491.630220
# 264474     7612.978110
# 293634    39713.381778
# 23315     -4509.251240
# Length: 331675, dtype: float64

# %%
### Посчитаем MAE

abs(X['Предсказание'] - Y).mean()
# Out:
# 13852.835311317305
